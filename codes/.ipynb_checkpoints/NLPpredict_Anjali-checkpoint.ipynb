# %% [markdown]
# test file for nlp packages that predict race to see acuuracy,the following are the packages using
#
# 1. ethnicolr
# The model uses US census data, the Florida voting registration data, and the Wikipedia data collected by Skiena and colleagues, to predict race and ethnicity based on first and last name or just the last name.
# The model provides 06 functions.
#
# Source: https://ethnicolr.readthedocs.io/ethnicolr.html#install
#
# 2. rethnicity
# The model is a Bidirectional Long Short-Term Memory (Bi-LSTM), a recurrent neural network architecture commonly used for natural language processing, was chosen as the model for our study. The Florida Voter Registration was used as the training and testing data.
#
# Source: https://cran.r-project.org/web/packages/rethnicity/rethnicity.pdf
#
# 3. raceBERT
# a transformer-based model for predict- ing race and ethnicity from character sequences in names, and an accom- panying python package. Using a transformer-based model trained on a U.S. Florida voter registration dataset1, the model predicts the likelihood of a name belonging to 5 U.S. census race categories (White, Black, His- panic, Asian & Pacific Islander, American Indian & Alaskan Native).
#
# Sources: https://arxiv.org/pdf/2112.03807.pdf
# https://pypi.org/project/racebert/
# https://huggingface.co/pparasurama/raceBERT
#
# The Prediction Process:
#
# owner ----> nlp ----> W: 70% NW: 30%
# geoid:059.... ----> W: 80% NW: 20%
#             .
#             .
#             .
#             .
# geoid:059.... ----> W: 60% NW: 40%
#             and use
#         min & max scale?
#           ex.
#             1 -----> 40

# %%
import pandas as pd


#data fram we will use to test the nlp models
mergent_true_df = pd.read_csv('../data/mergent_intellect_executives/sample.csv.xz')
mergent_true_df

#data frame with just the first and the last names
namesdf = pd.DataFrame(mergent_true_df, columns=['lastname', 'firstname'])
namesdf
#the orignal data frame contains 1067 names
# Out:
#             lastname firstname
# 0             Maigue   Richard
# 1              Fatah     Ifrah
# 2          Abu-hamda      Eyad
# 3            Degraft         J
# 4       Padwo-audick      Dara
# ...              ...       ...
# 1062  Sharifzadeh Na      Lily
# 1063              Na      Lily
# 1064             Kim    Ronnie
# 1065         Shihadh     Naser
# 1066           Lyall    Tricia
#
# [1067 rows x 2 columns]

# %% [markdown]
# # Ethnicolor:

# %%
import ethnicolr
from ethnicolr import census_ln, pred_census_ln

f = 'firstname'
l = 'lastname'

fname = pd.DataFrame(mergent_true_df, columns=[f])
lname = pd.DataFrame(mergent_true_df, columns=[l])
# Out:
# 2023-07-03 11:19:16.315110: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-03 11:19:16.318531: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-03 11:19:16.393882: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-03 11:19:16.394965: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-03 11:19:18.053781: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## censu_ln w/first

# %%
census_ln(fname, f, 2010)
#produces a sig. amount of null values
#does not predict the race automatically
# Out:
#     firstname pctwhite pctblack pctapi pctaian pct2prace pcthispanic
# 0     Richard    70.35    23.46    0.9    0.57      1.97        2.75
# 1       Ifrah    87.31     4.48    (S)       0       (S)        4.48
# 2        Eyad      NaN      NaN    NaN     NaN       NaN         NaN
# 3           J      NaN      NaN    NaN     NaN       NaN         NaN
# 4        Dara    41.34     6.89   41.7     (S)       (S)        5.65
# ..        ...      ...      ...    ...     ...       ...         ...
# 610     Terri    74.53    18.01    (S)     (S)      3.73         (S)
# 611      Lily    56.92    22.19   8.62       0      2.87         9.4
# 612    Ronnie    71.75    13.45   2.69     (S)       (S)        9.87
# 613     Naser    81.76     1.92   8.28       0      3.45         4.6
# 614    Tricia      NaN      NaN    NaN     NaN       NaN         NaN
#
# [615 rows x 7 columns]

# %% [markdown]
# ## censu_ln w/last

# %%
census_ln(fname, f, 2010)
#output is mostly null
# Out:
#     firstname pctwhite pctblack pctapi pctaian pct2prace pcthispanic
# 0     Richard    70.35    23.46    0.9    0.57      1.97        2.75
# 1       Ifrah    87.31     4.48    (S)       0       (S)        4.48
# 2        Eyad      NaN      NaN    NaN     NaN       NaN         NaN
# 3           J      NaN      NaN    NaN     NaN       NaN         NaN
# 4        Dara    41.34     6.89   41.7     (S)       (S)        5.65
# ..        ...      ...      ...    ...     ...       ...         ...
# 610     Terri    74.53    18.01    (S)     (S)      3.73         (S)
# 611      Lily    56.92    22.19   8.62       0      2.87         9.4
# 612    Ronnie    71.75    13.45   2.69     (S)       (S)        9.87
# 613     Naser    81.76     1.92   8.28       0      3.45         4.6
# 614    Tricia      NaN      NaN    NaN     NaN       NaN         NaN
#
# [615 rows x 7 columns]

# %% [markdown]
# ## pred_census_ln w lastnames

# %%
ldf = pred_census_ln(lname, l, 2010)
ldf
#actually predicts race in an output
#first names work too but the output is diff and produces smaller row number (predictions) - 615 to be exact
# Out:
# 2023-07-03 11:19:28.169967: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
#            lastname       api     black  hispanic     white   race
# 0            Maigue  0.024608  0.125805  0.041267  0.808320  white
# 1             Fatah  0.186252  0.329301  0.077460  0.406987  white
# 2         Abu-Hamda  0.834071  0.003604  0.004044  0.158281    api
# 3           Degraft  0.003943  0.018520  0.027489  0.950047  white
# 4      Padwo-Audick  0.007617  0.027304  0.026128  0.938950  white
# ..              ...       ...       ...       ...       ...    ...
# 912        Moreland  0.002145  0.101038  0.028627  0.868189  white
# 913  Sharifzadeh Na  0.366665  0.043451  0.012322  0.577562  white
# 914              Na  0.323868  0.022660  0.037510  0.615962  white
# 915         Shihadh  0.885730  0.047059  0.001922  0.065290    api
# 916           Lyall  0.007086  0.134766  0.027863  0.830285  white
#
# [917 rows x 6 columns]

# %% [markdown]
# ## pred_census_ln w firstnames

# %%
fdf = pred_census_ln(fname, f, 2010)
fdf
#as you can see this model outputs only 615 predictions
# Out:
#     firstname       api     black  hispanic     white      race
# 0     Richard  0.005425  0.222751  0.026621  0.745203     white
# 1       Ifrah  0.030944  0.553831  0.034017  0.381209     black
# 2        Eyad  0.025880  0.022798  0.021818  0.929505     white
# 3           J  0.461375  0.068442  0.085889  0.384294       api
# 4        Dara  0.457795  0.064153  0.121122  0.356931       api
# ..        ...       ...       ...       ...       ...       ...
# 610     Terri  0.005211  0.016933  0.119547  0.858308     white
# 611      Lily  0.005142  0.066140  0.029792  0.898927     white
# 612    Ronnie  0.007947  0.163154  0.030461  0.798438     white
# 613     Naser  0.008601  0.035153  0.027951  0.928295     white
# 614    Tricia  0.017301  0.003254  0.908098  0.071347  hispanic
#
# [615 rows x 6 columns]

# %%
#using the pred_census_ln(lname, l, 2010) data frame w/ prediction, i am transforming the data into something useful for the proj. 
transdf = pd.DataFrame(ldf, columns=['lastname', 'white'])
notw = list(1-transdf['white'])
transdf['not_white'] = notw


rce = list(list(ldf['race']))

transdf['race'] = rce

transdf

for r in list(transdf['race']):
      if r == "white":
         r = 0
      else:
         r = 1

transdf
# for r in rce:
#   print (r)
#transdf
#the 1's are going to be brought to the top of the data frame
#I added a prop not_white column and made it so that the race column used boolean values:
#1 if minority 
#0 if white

#i can do this for the firstname input of the function upon request as well
# Out:
#            lastname     white  not_white   race
# 0            Maigue  0.808320   0.191680  white
# 1             Fatah  0.406987   0.593013  white
# 2         Abu-Hamda  0.158281   0.841719    api
# 3           Degraft  0.950047   0.049953  white
# 4      Padwo-Audick  0.938950   0.061050  white
# ..              ...       ...        ...    ...
# 912        Moreland  0.868189   0.131811  white
# 913  Sharifzadeh Na  0.577562   0.422438  white
# 914              Na  0.615962   0.384038  white
# 915         Shihadh  0.065290   0.934710    api
# 916           Lyall  0.830285   0.169715  white
#
# [917 rows x 4 columns]

# %% [markdown]
# ## pred_wiki_ln w/ firstnames

# %%
from ethnicolr import pred_wiki_ln, pred_wiki_name
wikifirstdf = pred_wiki_ln(fname, 'firstname', num_iter=100, conf_int=.90)
#i like how this function has a confidence interval input 
wikifirstdf

#this does not produce many predictions with the first name --> 615
# Out:
# ['Asian,GreaterEastAsian,EastAsian', 'Asian,GreaterEastAsian,Japanese', 'Asian,IndianSubContinent', 'GreaterAfrican,Africans', 'GreaterAfrican,Muslim', 'GreaterEuropean,British', 'GreaterEuropean,EastEuropean', 'GreaterEuropean,Jewish', 'GreaterEuropean,WestEuropean,French', 'GreaterEuropean,WestEuropean,Germanic', 'GreaterEuropean,WestEuropean,Hispanic', 'GreaterEuropean,WestEuropean,Italian', 'GreaterEuropean,WestEuropean,Nordic']
#     firstname  Asian,GreaterEastAsian,EastAsian_mean  \
# 0     Richard                               0.009419
# 1       Ifrah                               0.005826
# 2        Eyad                               0.368449
# 3           J                               0.073061
# 4        Dara                               0.013630
# ..        ...                                    ...
# 610     Terri                                    NaN
# 611      Lily                                    NaN
# 612    Ronnie                                    NaN
# 613     Naser                                    NaN
# 614    Tricia                                    NaN
#
#      Asian,GreaterEastAsian,EastAsian_std  \
# 0                                0.005510
# 1                                0.007453
# 2                                0.174416
# 3                                0.030319
# 4                                0.008741
# ..                                    ...
# 610                                   NaN
# 611                                   NaN
# 612                                   NaN
# 613                                   NaN
# 614                                   NaN
#
#      Asian,GreaterEastAsian,EastAsian_lb  Asian,GreaterEastAsian,EastAsian_ub  \
# 0                               0.003968                             0.019692
# 1                               0.000773                             0.016731
# 2                               0.110778                             0.633629
# 3                               0.046609                             0.128356
# 4                               0.004796                             0.028221
# ..                                   ...                                  ...
# 610                                  NaN                                  NaN
# 611                                  NaN                                  NaN
# 612                                  NaN                                  NaN
# 613                                  NaN                                  NaN
# 614                                  NaN                                  NaN
#
#      Asian,GreaterEastAsian,Japanese_mean  \
# 0                                0.002102
# 1                                0.017563
# 2                                0.009293
# 3                                0.024809
# 4                                0.252259
# ..                                    ...
# 610                                   NaN
# 611                                   NaN
# 612                                   NaN
# 613                                   NaN
# 614                                   NaN
#
#      Asian,GreaterEastAsian,Japanese_std  Asian,GreaterEastAsian,Japanese_lb  \
# 0                               0.001337                            0.000637
# 1                               0.015003                            0.003152
# 2                               0.005483                            0.002731
# 3                               0.007872                            0.016412
# 4                               0.129988                            0.091523
# ..                                   ...                                 ...
# 610                                  NaN                                 NaN
# 611                                  NaN                                 NaN
# 612                                  NaN                                 NaN
# 613                                  NaN                                 NaN
# 614                                  NaN                                 NaN
#
#      Asian,GreaterEastAsian,Japanese_ub  Asian,IndianSubContinent_mean  ...  \
# 0                              0.004283                       0.003458  ...
# 1                              0.049032                       0.012378  ...
# 2                              0.021319                       0.156688  ...
# 3                              0.038934                       0.068725  ...
# 4                              0.478921                       0.058166  ...
# ..                                  ...                            ...  ...
# 610                                 NaN                            NaN  ...
# 611                                 NaN                            NaN  ...
# 612                                 NaN                            NaN  ...
# 613                                 NaN                            NaN  ...
# 614                                 NaN                            NaN  ...
#
#      GreaterEuropean,WestEuropean,Hispanic_ub  \
# 0                                    0.030669
# 1                                    0.054537
# 2                                    0.018896
# 3                                    0.069268
# 4                                    0.397759
# ..                                        ...
# 610                                       NaN
# 611                                       NaN
# 612                                       NaN
# 613                                       NaN
# 614                                       NaN
#
#      GreaterEuropean,WestEuropean,Italian_mean  \
# 0                                     0.007379
# 1                                     0.030633
# 2                                     0.018820
# 3                                     0.216175
# 4                                     0.069623
# ..                                         ...
# 610                                        NaN
# 611                                        NaN
# 612                                        NaN
# 613                                        NaN
# 614                                        NaN
#
#      GreaterEuropean,WestEuropean,Italian_std  \
# 0                                    0.003548
# 1                                    0.024297
# 2                                    0.011980
# 3                                    0.037872
# 4                                    0.032959
# ..                                        ...
# 610                                       NaN
# 611                                       NaN
# 612                                       NaN
# 613                                       NaN
# 614                                       NaN
#
#      GreaterEuropean,WestEuropean,Italian_lb  \
# 0                                   0.003087
# 1                                   0.005922
# 2                                   0.005286
# 3                                   0.158940
# 4                                   0.026478
# ..                                       ...
# 610                                      NaN
# 611                                      NaN
# 612                                      NaN
# 613                                      NaN
# 614                                      NaN
#
#      GreaterEuropean,WestEuropean,Italian_ub  \
# 0                                   0.012291
# 1                                   0.083522
# 2                                   0.037174
# 3                                   0.286622
# 4                                   0.124767
# ..                                       ...
# 610                                      NaN
# 611                                      NaN
# 612                                      NaN
# 613                                      NaN
# 614                                      NaN
#
#      GreaterEuropean,WestEuropean,Nordic_mean  \
# 0                                    0.005080
# 1                                    0.021327
# 2                                    0.023177
# 3                                    0.040993
# 4                                    0.007806
# ..                                        ...
# 610                                       NaN
# 611                                       NaN
# 612                                       NaN
# 613                                       NaN
# 614                                       NaN
#
#      GreaterEuropean,WestEuropean,Nordic_std  \
# 0                                   0.003242
# 1                                   0.013505
# 2                                   0.028023
# 3                                   0.008082
# 4                                   0.004687
# ..                                       ...
# 610                                      NaN
# 611                                      NaN
# 612                                      NaN
# 613                                      NaN
# 614                                      NaN
#
#      GreaterEuropean,WestEuropean,Nordic_lb  \
# 0                                  0.001717
# 1                                  0.005287
# 2                                  0.005527
# 3                                  0.030068
# 4                                  0.002522
# ..                                      ...
# 610                                     NaN
# 611                                     NaN
# 612                                     NaN
# 613                                     NaN
# 614                                     NaN
#
#      GreaterEuropean,WestEuropean,Nordic_ub  \
# 0                                  0.011524
# 1                                  0.050375
# 2                                  0.052149
# 3                                  0.055810
# 4                                  0.016591
# ..                                      ...
# 610                                     NaN
# 611                                     NaN
# 612                                     NaN
# 613                                     NaN
# 614                                     NaN
#
#                                      race
# 0                 GreaterEuropean,British
# 1                  GreaterEuropean,Jewish
# 2        Asian,GreaterEastAsian,EastAsian
# 3    GreaterEuropean,WestEuropean,Italian
# 4         Asian,GreaterEastAsian,Japanese
# ..                                    ...
# 610                                   NaN
# 611                                   NaN
# 612                                   NaN
# 613                                   NaN
# 614                                   NaN
#
# [615 rows x 54 columns]

# %% [markdown]
# ## pred_wiki_ln w/lastnames

# %%
wikilastdf = pred_wiki_ln(lname, 'lastname', num_iter=100, conf_int=.90)

wikilastdf
#this produces more predictions than the first name -->917
# Out:
# ['Asian,GreaterEastAsian,EastAsian', 'Asian,GreaterEastAsian,Japanese', 'Asian,IndianSubContinent', 'GreaterAfrican,Africans', 'GreaterAfrican,Muslim', 'GreaterEuropean,British', 'GreaterEuropean,EastEuropean', 'GreaterEuropean,Jewish', 'GreaterEuropean,WestEuropean,French', 'GreaterEuropean,WestEuropean,Germanic', 'GreaterEuropean,WestEuropean,Hispanic', 'GreaterEuropean,WestEuropean,Italian', 'GreaterEuropean,WestEuropean,Nordic']
#            lastname  Asian,GreaterEastAsian,EastAsian_mean  \
# 0            Maigue                               0.072561
# 1             Fatah                               0.001892
# 2         Abu-Hamda                               0.018211
# 3           Degraft                               0.006073
# 4      Padwo-Audick                               0.001361
# ..              ...                                    ...
# 912        Moreland                                    NaN
# 913  Sharifzadeh Na                                    NaN
# 914              Na                                    NaN
# 915         Shihadh                                    NaN
# 916           Lyall                                    NaN
#
#      Asian,GreaterEastAsian,EastAsian_std  \
# 0                                0.056941
# 1                                0.002540
# 2                                0.014261
# 3                                0.004306
# 4                                0.001492
# ..                                    ...
# 912                                   NaN
# 913                                   NaN
# 914                                   NaN
# 915                                   NaN
# 916                                   NaN
#
#      Asian,GreaterEastAsian,EastAsian_lb  Asian,GreaterEastAsian,EastAsian_ub  \
# 0                               0.016448                             0.201477
# 1                               0.000298                             0.005678
# 2                               0.004319                             0.044382
# 3                               0.001740                             0.014151
# 4                               0.000141                             0.004091
# ..                                   ...                                  ...
# 912                                  NaN                                  NaN
# 913                                  NaN                                  NaN
# 914                                  NaN                                  NaN
# 915                                  NaN                                  NaN
# 916                                  NaN                                  NaN
#
#      Asian,GreaterEastAsian,Japanese_mean  \
# 0                                0.148396
# 1                                0.000927
# 2                                0.421048
# 3                                0.006272
# 4                                0.004313
# ..                                    ...
# 912                                   NaN
# 913                                   NaN
# 914                                   NaN
# 915                                   NaN
# 916                                   NaN
#
#      Asian,GreaterEastAsian,Japanese_std  Asian,GreaterEastAsian,Japanese_lb  \
# 0                               0.127147                            0.018687
# 1                               0.002031                            0.000108
# 2                               0.241020                            0.044445
# 3                               0.006422                            0.000953
# 4                               0.005684                            0.000384
# ..                                   ...                                 ...
# 912                                  NaN                                 NaN
# 913                                  NaN                                 NaN
# 914                                  NaN                                 NaN
# 915                                  NaN                                 NaN
# 916                                  NaN                                 NaN
#
#      Asian,GreaterEastAsian,Japanese_ub  Asian,IndianSubContinent_mean  ...  \
# 0                              0.398600                       0.002201  ...
# 1                              0.002600                       0.083564  ...
# 2                              0.793831                       0.011933  ...
# 3                              0.018056                       0.002210  ...
# 4                              0.017371                       0.017453  ...
# ..                                  ...                            ...  ...
# 912                                 NaN                            NaN  ...
# 913                                 NaN                            NaN  ...
# 914                                 NaN                            NaN  ...
# 915                                 NaN                            NaN  ...
# 916                                 NaN                            NaN  ...
#
#      GreaterEuropean,WestEuropean,Hispanic_ub  \
# 0                                    0.133939
# 1                                    0.054779
# 2                                    0.072124
# 3                                    0.043575
# 4                                    0.038949
# ..                                        ...
# 912                                       NaN
# 913                                       NaN
# 914                                       NaN
# 915                                       NaN
# 916                                       NaN
#
#      GreaterEuropean,WestEuropean,Italian_mean  \
# 0                                     0.007386
# 1                                     0.016940
# 2                                     0.002636
# 3                                     0.009854
# 4                                     0.011109
# ..                                         ...
# 912                                        NaN
# 913                                        NaN
# 914                                        NaN
# 915                                        NaN
# 916                                        NaN
#
#      GreaterEuropean,WestEuropean,Italian_std  \
# 0                                    0.004716
# 1                                    0.008421
# 2                                    0.002901
# 3                                    0.007931
# 4                                    0.012804
# ..                                        ...
# 912                                       NaN
# 913                                       NaN
# 914                                       NaN
# 915                                       NaN
# 916                                       NaN
#
#      GreaterEuropean,WestEuropean,Italian_lb  \
# 0                                   0.001929
# 1                                   0.007004
# 2                                   0.000716
# 3                                   0.002679
# 4                                   0.001682
# ..                                       ...
# 912                                      NaN
# 913                                      NaN
# 914                                      NaN
# 915                                      NaN
# 916                                      NaN
#
#      GreaterEuropean,WestEuropean,Italian_ub  \
# 0                                   0.017437
# 1                                   0.037128
# 2                                   0.008488
# 3                                   0.022950
# 4                                   0.036165
# ..                                       ...
# 912                                      NaN
# 913                                      NaN
# 914                                      NaN
# 915                                      NaN
# 916                                      NaN
#
#      GreaterEuropean,WestEuropean,Nordic_mean  \
# 0                                    0.001736
# 1                                    0.002448
# 2                                    0.005123
# 3                                    0.029580
# 4                                    0.010678
# ..                                        ...
# 912                                       NaN
# 913                                       NaN
# 914                                       NaN
# 915                                       NaN
# 916                                       NaN
#
#      GreaterEuropean,WestEuropean,Nordic_std  \
# 0                                   0.001447
# 1                                   0.001520
# 2                                   0.005256
# 3                                   0.035469
# 4                                   0.015986
# ..                                       ...
# 912                                      NaN
# 913                                      NaN
# 914                                      NaN
# 915                                      NaN
# 916                                      NaN
#
#      GreaterEuropean,WestEuropean,Nordic_lb  \
# 0                                  0.000408
# 1                                  0.000997
# 2                                  0.000825
# 3                                  0.003958
# 4                                  0.001016
# ..                                      ...
# 912                                     NaN
# 913                                     NaN
# 914                                     NaN
# 915                                     NaN
# 916                                     NaN
#
#      GreaterEuropean,WestEuropean,Nordic_ub                             race
# 0                                  0.003779          GreaterEuropean,British
# 1                                  0.005687            GreaterAfrican,Muslim
# 2                                  0.013399  Asian,GreaterEastAsian,Japanese
# 3                                  0.075026          GreaterEuropean,British
# 4                                  0.031391          GreaterEuropean,British
# ..                                      ...                              ...
# 912                                     NaN                              NaN
# 913                                     NaN                              NaN
# 914                                     NaN                              NaN
# 915                                     NaN                              NaN
# 916                                     NaN                              NaN
#
# [917 rows x 54 columns]

# %% [markdown]
# ## pred_wiki_name (this takes both the first and last names)

# %%
from ethnicolr import pred_wiki_ln, pred_wiki_name
wikifulldf = pred_wiki_name(namesdf,'lastname', 'firstname', conf_int=0.9)
wikifulldf

#let us rearrange columns so that race prediction is in the first position after the name because I'm sure we dont want to scroll down the data frame..
cols = [wikifulldf.columns[-1]] + [col for col in wikifulldf if col != wikifulldf.columns[-1]]
wikifulldf = wikifulldf[cols]

wikifulldf
#produces some null values but it does list most items from the original dataframe
# Out:
# ['Asian,GreaterEastAsian,EastAsian', 'Asian,GreaterEastAsian,Japanese', 'Asian,IndianSubContinent', 'GreaterAfrican,Africans', 'GreaterAfrican,Muslim', 'GreaterEuropean,British', 'GreaterEuropean,EastEuropean', 'GreaterEuropean,Jewish', 'GreaterEuropean,WestEuropean,French', 'GreaterEuropean,WestEuropean,Germanic', 'GreaterEuropean,WestEuropean,Hispanic', 'GreaterEuropean,WestEuropean,Italian', 'GreaterEuropean,WestEuropean,Nordic']
#                          race        lastname firstname  \
# 0     GreaterEuropean,British          Maigue   Richard
# 1       GreaterAfrican,Muslim           Fatah     Ifrah
# 2       GreaterAfrican,Muslim       Abu-hamda      Eyad
# 3      GreaterEuropean,Jewish         Degraft         J
# 4     GreaterEuropean,British    Padwo-audick      Dara
# ...                       ...             ...       ...
# 1044                      NaN  Sharifzadeh Na      Lily
# 1045                      NaN              Na      Lily
# 1046                      NaN             Kim    Ronnie
# 1047                      NaN         Shihadh     Naser
# 1048                      NaN           Lyall    Tricia
#
#       Asian,GreaterEastAsian,EastAsian_mean  \
# 0                                  0.007302
# 1                                  0.000237
# 2                                  0.000289
# 3                                  0.010048
# 4                                  0.007027
# ...                                     ...
# 1044                                    NaN
# 1045                                    NaN
# 1046                                    NaN
# 1047                                    NaN
# 1048                                    NaN
#
#       Asian,GreaterEastAsian,EastAsian_std  \
# 0                                 0.008992
# 1                                 0.000489
# 2                                 0.000365
# 3                                 0.005628
# 4                                 0.006974
# ...                                    ...
# 1044                                   NaN
# 1045                                   NaN
# 1046                                   NaN
# 1047                                   NaN
# 1048                                   NaN
#
#       Asian,GreaterEastAsian,EastAsian_lb  \
# 0                                0.001028
# 1                                0.000012
# 2                                0.000033
# 3                                0.003517
# 4                                0.001062
# ...                                   ...
# 1044                                  NaN
# 1045                                  NaN
# 1046                                  NaN
# 1047                                  NaN
# 1048                                  NaN
#
#       Asian,GreaterEastAsian,EastAsian_ub  \
# 0                                0.024093
# 1                                0.000696
# 2                                0.000885
# 3                                0.021426
# 4                                0.020116
# ...                                   ...
# 1044                                  NaN
# 1045                                  NaN
# 1046                                  NaN
# 1047                                  NaN
# 1048                                  NaN
#
#       Asian,GreaterEastAsian,Japanese_mean  \
# 0                                 0.004575
# 1                                 0.000057
# 2                                 0.001903
# 3                                 0.008297
# 4                                 0.002343
# ...                                    ...
# 1044                                   NaN
# 1045                                   NaN
# 1046                                   NaN
# 1047                                   NaN
# 1048                                   NaN
#
#       Asian,GreaterEastAsian,Japanese_std  Asian,GreaterEastAsian,Japanese_lb  \
# 0                                0.005540                            0.000696
# 1                                0.000074                            0.000005
# 2                                0.002872                            0.000035
# 3                                0.004858                            0.002914
# 4                                0.002212                            0.000200
# ...                                   ...                                 ...
# 1044                                  NaN                                 NaN
# 1045                                  NaN                                 NaN
# 1046                                  NaN                                 NaN
# 1047                                  NaN                                 NaN
# 1048                                  NaN                                 NaN
#
#       ...  GreaterEuropean,WestEuropean,Hispanic_lb  \
# 0     ...                                  0.003673
# 1     ...                                  0.000395
# 2     ...                                  0.000149
# 3     ...                                  0.024909
# 4     ...                                  0.009110
# ...   ...                                       ...
# 1044  ...                                       NaN
# 1045  ...                                       NaN
# 1046  ...                                       NaN
# 1047  ...                                       NaN
# 1048  ...                                       NaN
#
#       GreaterEuropean,WestEuropean,Hispanic_ub  \
# 0                                     0.084301
# 1                                     0.005067
# 2                                     0.002216
# 3                                     0.096227
# 4                                     0.063817
# ...                                        ...
# 1044                                       NaN
# 1045                                       NaN
# 1046                                       NaN
# 1047                                       NaN
# 1048                                       NaN
#
#       GreaterEuropean,WestEuropean,Italian_mean  \
# 0                                      0.014518
# 1                                      0.004286
# 2                                      0.003589
# 3                                      0.020582
# 4                                      0.021346
# ...                                         ...
# 1044                                        NaN
# 1045                                        NaN
# 1046                                        NaN
# 1047                                        NaN
# 1048                                        NaN
#
#       GreaterEuropean,WestEuropean,Italian_std  \
# 0                                     0.013135
# 1                                     0.004982
# 2                                     0.002623
# 3                                     0.012739
# 4                                     0.012826
# ...                                        ...
# 1044                                       NaN
# 1045                                       NaN
# 1046                                       NaN
# 1047                                       NaN
# 1048                                       NaN
#
#       GreaterEuropean,WestEuropean,Italian_lb  \
# 0                                    0.002874
# 1                                    0.000725
# 2                                    0.000857
# 3                                    0.007625
# 4                                    0.007577
# ...                                       ...
# 1044                                      NaN
# 1045                                      NaN
# 1046                                      NaN
# 1047                                      NaN
# 1048                                      NaN
#
#       GreaterEuropean,WestEuropean,Italian_ub  \
# 0                                    0.042807
# 1                                    0.013813
# 2                                    0.008507
# 3                                    0.039688
# 4                                    0.049720
# ...                                       ...
# 1044                                      NaN
# 1045                                      NaN
# 1046                                      NaN
# 1047                                      NaN
# 1048                                      NaN
#
#       GreaterEuropean,WestEuropean,Nordic_mean  \
# 0                                     0.003786
# 1                                     0.005646
# 2                                     0.005411
# 3                                     0.016440
# 4                                     0.026425
# ...                                        ...
# 1044                                       NaN
# 1045                                       NaN
# 1046                                       NaN
# 1047                                       NaN
# 1048                                       NaN
#
#       GreaterEuropean,WestEuropean,Nordic_std  \
# 0                                    0.005320
# 1                                    0.008548
# 2                                    0.011907
# 3                                    0.012074
# 4                                    0.026041
# ...                                       ...
# 1044                                      NaN
# 1045                                      NaN
# 1046                                      NaN
# 1047                                      NaN
# 1048                                      NaN
#
#       GreaterEuropean,WestEuropean,Nordic_lb  \
# 0                                   0.000333
# 1                                   0.000404
# 2                                   0.000318
# 3                                   0.004393
# 4                                   0.002563
# ...                                      ...
# 1044                                     NaN
# 1045                                     NaN
# 1046                                     NaN
# 1047                                     NaN
# 1048                                     NaN
#
#       GreaterEuropean,WestEuropean,Nordic_ub
# 0                                   0.012417
# 1                                   0.017350
# 2                                   0.012699
# 3                                   0.040064
# 4                                   0.081336
# ...                                      ...
# 1044                                     NaN
# 1045                                     NaN
# 1046                                     NaN
# 1047                                     NaN
# 1048                                     NaN
#
# [1049 rows x 55 columns]

# %%
#attempting to sort
ethnicitylist = ['Asian,GreaterEastAsian,EastAsian', 'Asian,GreaterEastAsian,Japanese',
'Asian,IndianSubContinent', 'GreaterAfrican,Africans', 'GreaterAfrican,Muslim',
 'GreaterEuropean,British', 'GreaterEuropean,EastEuropean',
 'GreaterEuropean,Jewish', 'GreaterEuropean,WestEuropean,French', 
 'GreaterEuropean,WestEuropean,Germanic', 'GreaterEuropean,WestEuropean,Hispanic', 
 'GreaterEuropean,WestEuropean,Italian', 'GreaterEuropean,WestEuropean,Nordic']

white = ['GreaterEuropean,WestEuropean,Italian', 'GreaterEuropean,WestEuropean,Nordic',
         'GreaterEuropean,WestEuropean,Germanic', 'GreaterEuropean,WestEuropean,French',
         'GreaterEuropean,Jewish', 'GreaterEuropean,British', 'GreaterEuropean,EastEuropean']

testdf = pd.DataFrame()
